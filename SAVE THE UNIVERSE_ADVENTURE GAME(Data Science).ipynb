# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Oct 16 16:57:55 2019

@author: debasishbiswal
"""

#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Oct 14 22:09:07 2019

@author: debasishbiswal
"""
"""
DocString:
    
    A) Introduction:
      This game you are about to play is called 'Save the Universe' and
      it is a game based on Marvel Cinematic Universe. 
      To win this game you have to pass three levels. After winning
      level 1, You will be able to enter level 2 and after, if you manage
      to beat level 2 you will be able to face off level 3. In this game 
      you will have the option to choose your Super Hero and you will have to
      face several challenges.
      Once you defeated the villain, you win the game. The rules are
      pretty simple, you have to choose from 3 different options. 
      It is pretty simple, just follow the instruction and save the city. 
      Have fun.
    
    Round 1 is the test of your strength
    Round 2 is the test of your knowledge about Marvel Cinematic Universe and strength
    Round 3 you will need strength, knowledge and luck

    B) Known Bugs and/or Errors:
    None.

"""
import random
import time
from sys import exit
# %matplotlib inline

class bcolors:
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    Red = '\033[91m'
    Green = '\033[92m'
    Blue = '\033[94m'
    Cyan = '\033[96m'
    White = '\033[97m'
    Yellow = '\033[93m'
    Magenta = '\033[95m'
    Grey = '\033[90m'
    Black = '\033[90m'
    Default = '\033[99m'

print("""
      This game is known as Save the Universe and it is a game based on the Marvel Cinematic Universe. 
You must pass three levels to win this game. After you complete level 1, you can enter level 2 
and you can enter level 3 once you complete level 2. 
""")
time.sleep(5)

print("""In this game, you can choose your Super Hero and with them you will face a number of challenges.
You win the game by defeating the main villain, Thanos, the big purple grape.
      """)
print("\nHello and welcome. Are you ready to 'Save the Universe'!!\n")
input('<Press Enter to continue>\n')
time.sleep(3)
print(bcolors.Yellow +""" 
 (                                       )                  )  (                 (    (         
 )\ )    (                     *   )  ( /(               ( /(  )\ )              )\ ) )\ )      
(()/(    )\     (   (   (    ` )  /(  )\()) (        (   )\())(()/( (   (   (   (()/((()/( (    
 /(_))((((_)(   )\  )\  )\    ( )(_))((_)\  )\       )\ ((_)\  /(_)))\  )\  )\   /(_))/(_)))\   
(_))   )\ _ )\ ((_)((_)((_)  (_(_())  _((_)((_)   _ ((_) _((_)(_)) ((_)((_)((_) (_)) (_)) ((_)  
/ __|  (_)_\(_)\ \ / / | __| |_   _| | || || __| | | | || \| ||_ _|\ \ / / | __|| _ \/ __|| __| 
\__ \   / _ \   \ V /  | _|    | |   | __ || _|  | |_| || .` | | |  \ V /  | _| |   /\__ \| _|  
|___/  /_/ \_\   \_/   |___|   |_|   |_||_||___|  \___/ |_|\_||___|  \_/   |___||_|_\|___/|___| 
                                                                                                  
                                                                                                      """ + bcolors.BOLD)
def start_1():
    start = input(bcolors.Blue +" Are you excited to 'Save the Universe' ? \n1.Yes \n2.No \nAnswer: " + bcolors.BOLD)
    if start == '1':
        print(bcolors.Green + "Perfect!! You're awesome and ready to play" + bcolors.BOLD)
    elif start == '2':
        print(bcolors.Red + " Aah!! I'm sorry but you can't go back now. Your city... " + bcolors.BOLD)
        for letter in '...':
            print(letter)
        print(bcolors.Red + "No! The Universe needs you!" + bcolors.BOLD)
        print("Let's play")
    else:
        print(bcolors.Red + "Invalid selection, You're only allowed to press 1 or 2" + bcolors.ENDC)
        print("\n")
        start_1()

#Heroes
class ironman(object):
    name = "Iron Man aka Tony Stark"
    health = 10
    strength = 7
    intelligence = 30
    power = 5
    agility = 65
    
class thor(object):
    name = "Thor Odinson"
    health = 10
    strength = 7
    intelligence = 8
    power = 40
    agility = 40
    
class black_widow(object):
    name = "Black Widow aka Natasha Romanoff"
    health = 10
    strength = 7
    intelligence = 14
    power = 5
    agility = 75
    
#Enemies
class redskull(object):
    name = "Redskull"
    health = 8
    strength = 3
    intelligence = 15
    power = 50
    agility = 50
    
class loki(object):
    name = "Loki"
    health = 8
    strength = 3
    intelligence = 12
    power = 25
    agility = 50
    
    
class taskmaster(object):
    name = "Taskmaster"
    health = 8
    strength = 2
    intelligence = 10
    power = 10
    agility = 20
    
class thanos(object):
    name = "Thanos"
    health = 20
    strength = 12
    intelligence = 25
    power = 28
    agility = 40

    
def myhero():
    import numpy as np
    from matplotlib import pyplot as plt
    print("Select your Super Hero character")
    selection = input("1.Iron Man \n2.Thor \n3.Black Widow \nAnswer:")
    if selection == "1":
        hero = ironman
        
        print(bcolors.Red + " your chosen super hero is Iron Man & these are his data" + bcolors.ENDC)
        print(bcolors.Red + """
  ___ ____   ___  _   _   __  __    _    _   _ 
 |_ _|  _ \ / _ \| \ | | |  \/  |  / \  | \ | |
  | || |_) | | | |  \| | | |\/| | / _ \ |  \| |
  | ||  _ <| |_| | |\  | | |  | |/ ___ \| |\  |
 |___|_| \_\\___/|_| \_| |_|  |_/_/   \_\_| \_|
                                               
                                              """ + bcolors.ENDC)
        print("health :", hero.health)
        print("strength :", hero.strength)
        print("intelligence :", hero.intelligence)
        print("power :", hero.power)
        print("agility :", hero.agility)
        stats = ['Strength', 'Health', 'Intelligence', 'Power', 'Agility']
        numbers = ['7', '10', '30', '5', '65']
        ind = np.arange(len(stats))
        ind
        plt.bar(ind, numbers)
        plt.xticks(ind, stats)
        plt.show()
        return hero

    elif selection == "2":
        hero = thor
        print(bcolors.Blue + "your chosen super hero is Thor & these are his data" + bcolors.ENDC)
        print(bcolors.Blue + """ 
  _____ _   _  ___  ____  
 |_   _| | | |/ _ \|  _ \ 
   | | | |_| | | | | |_) |
   | | |  _  | |_| |  _ < 
   |_| |_| |_|\___/|_| \_\
                          
                          """ + bcolors.ENDC)
        print("health :", hero.health)
        print("strength :", hero.strength)
        print("intelligence :", hero.intelligence)
        print("power :", hero.power)
        print("agility :", hero.agility)
        stats = ['Strength', 'Health', 'Intelligence', 'Power', 'Agility']
        numbers = ['7', '10', '8', '40', '40']
        ind = np.arange(len(stats))
        ind
        plt.bar(ind, numbers)
        plt.xticks(ind, stats)
        plt.show()
        return hero
   
    elif selection == "3":
        hero = black_widow
        print(bcolors.Black + "your chosen super hero is Black Widow & these are her data" + bcolors.ENDC)
        print(bcolors.Black + """
  ____  _        _    ____ _  __ __        _____ ____   _____        __
 | __ )| |      / \  / ___| |/ / \ \      / /_ _|  _ \ / _ \ \      / /
 |  _ \| |     / _ \| |   | ' /   \ \ /\ / / | || | | | | | \ \ /\ / / 
 | |_) | |___ / ___ \ |___| . \    \ V  V /  | || |_| | |_| |\ V  V /  
 |____/|_____/_/   \_\____|_|\_\    \_/\_/  |___|____/ \___/  \_/\_/   
                                                                    """ + bcolors.ENDC)
        print("health :", hero.health)
        print("strength :", hero.strength)
        print("intelligence :", hero.intelligence)
        print("power :", hero.power)
        print("agility :", hero.agility)
        stats = ['Strength', 'Health', 'Intelligence', 'Power', 'Agility']
        numbers = ['7', '10', '14', '5', '75']
        ind = np.arange(len(stats))
        ind
        plt.bar(ind, numbers)
        plt.xticks(ind, stats)
        plt.show()
        return hero
    else :
        print("Invalid Selection, only press 1,2 or 3")
        myhero()
        
def myvillain(redskull, loki, taskmaster):
    villainlist = [redskull, loki, taskmaster]
    chance = random.randint(0,2)
    villain = villainlist[chance]
    return villain

def fail():
    print("""Oh No!! He defeated you. You died. 
    Thanos arrived after his minion and destroyed the Earth, 
    killed everyone you hold dear, and wiped out the Universe.
    """)
    print(bcolors.Red + """
╦ ╦╔═╗╦ ╦  ╔═╗╔═╗╦╦  ╔═╗╔╦╗
╚╦╝║ ║║ ║  ╠╣ ╠═╣║║  ║╣  ║║
 ╩ ╚═╝╚═╝  ╚  ╩ ╩╩╩═╝╚═╝═╩╝""" + bcolors.ENDC)
    exit(0)



def battleground():
    villain = myvillain(redskull, loki, taskmaster)
    print("Meanwhile in San Francisco", villain.name, "has appeared,\nto steal the space stone.")
    print("\n")
    time.sleep(2)
    print("The space stone is with Dr. Abdul Samad who works at Oscorp Industries in Sillicon Valley")
    print("\n")
    time.sleep(2)
    print("You have to stop", villain.name, "and his army from stealing the stone and you have to fight him")
    for letter in '...':
        print(letter)
        time.sleep(2)
    print("To hope to defeat him you have 3 options")
    print("\n")
    while villain.health > 0:
        choice = input("1. Hand to hand combat \n2. Supersonic blast \n3. Run to hide " )
        if choice == "1":
            print("You used hand to hand combat to attack the", villain.name)
            hitchance = random.randint(0,10)
            if hitchance > 3:
                villain.health = villain.health - hero.strength
                print("You succesfully attacked", villain.name, " and his health decreased to", villain.health )
                print(villain.health)
                if villain.health > 0:
                    hero.health = hero.health - villain.strength
                    print(villain.name, " attacked you and your health decreased to", hero.health)
                    if hero.health <= 0:
                        fail()
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
                    
                else :
                    print("Hurray! You have vanquished the evil", villain.name)
                    print("\n")
                    time.sleep(2)
                    print("For safekeeping you took the stone from Dr. Abdul & sent it to Dr. Aparna's facility.")
                    for letter in '...':
                        print(letter)
                        time.sleep(2)
                    print("You hope that by doing so you can avoid more casualties, and prevent Thanos from executing his evil, horrible, plan.")
                    print("\n")
                    stage_2(villain)
                
            else:
                print("You tried to attack but" ,villain.name, " is using his shield and your attack failed")
                hero.health = hero.health - villain.strength
                print("Following the deflection of your attack", villain.name, "attacked you & you took full damage. Your health is", hero.health)
                if hero.health <= 0:
                    fail()
                    break
                else:
                    print("you have 3 options")
                    print("\n")
                    
    
                

        elif choice == "2":
            print("You used supersonic blast to attack", villain.name)
            hitchance = random.randint(0,10)
            if hitchance > 3:
                villain.health = villain.health - hero.strength
                print("You succesfully attacked", villain.name, " and his health decreased to", villain.health )
                print("\n")
                time.sleep(2)
                
                if villain.health > 0:
                    hero.health = hero.health - villain.strength
                    print("Even with this damage", villain.name, "attacked you and you took such a hit that your health decreased to", hero.health)
                    print("\n")
                    time.sleep(2)
                    if hero.health <= 0:
                        fail()
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
                    
                else :
                    print("Cheers!! You have defeated the dastardly", villain.name)
                    print("\n")
                    time.sleep(2)
                    print("For safekeeping you took the stone from Dr. Abdul & sent it to Dr. Aparna's facility.")
                    for letter in '...':
                        print(letter)
                        time.sleep(2)
                    print("You hope that by doing so you can avoid more casualties, and prevent Thanos from executing his evil, horrible, plan.")
                    print("\n")
                    stage_2(villain)
                    
            else:
                print("You tried to attack but" ,villain.name, " is using his shield and your attack failed")
                hero.health = hero.health - villain.strength
                print("Following the deflection of your attack", villain.name, "attacked you & you took full damage. Your health is", hero.health)
                if hero.health <= 0:
                    fail()
                    break
                else:
                    print("you have 3 options")
                    print("\n")
                
        elif choice == "3":
            print("You try to hide to do more research on his possible weaknesses")
            print("\n")
            time.sleep(2)
            hitchance = random.randint(0,10)
            if hitchance > 3:
                print("You are running to hide in an alleyway between the buildings and ", villain.name, "is looking for you" )
                print("\n")
                time.sleep(2)
                
                if villain.health > 0:
                    hero.health = hero.health - villain.strength
                    print( "Oh no!!", villain.name, "found you and attacked you from behind and your health decreased to", hero.health)
                    print("\n")
                    time.sleep(2)
                    if hero.health <= 0:
                        fail()
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
                    
                else :
                    print("Cheers!! You have defeated the dastardly", villain.name)
                    print("\n")
                    time.sleep(2)
                    print("For safekeeping you took the stone from Dr. Abdul & sent it to Dr. Aparna's facility.")
                    for letter in '...':
                        print(letter)
                        time.sleep(2)
                    print("You hope that by doing so you can avoid more casualties, and prevent Thanos from executing his evil, horrible, plan.")
                    time.sleep(2)
                    print("\n")
                    stage_2(villain)
                
            else:
                print("You tried to attack but" ,villain.name, " is using his shield and your attack failed miserably")
                print("\n")
                time.sleep(2)
                hero.health = hero.health - villain.strength
                print("Using that opportunity", villain.name, "attacked you & you took full damage like the little weakling you are. Your health is", hero.health)
                print("\n")
                time.sleep(2)
                if hero.health <= 0:
                    fail()
                    break
                else:
                    print("you have 3 options")
                    print("\n")
                
                
        else:
            print("Invalid Selection, only press 1,2 or 3")
            print("\n")

def stage_2(villain):
    villain.health = 16 
    hero.health = 10
    hero.strength = 10
    for letter in '...':
        print(letter)
    print(bcolors.BOLD + "Suddenly you feel a sort of shift in the air. You look around trying to find the source of your discomfort. You look up to the sky when you feel a strong wind blow.", bcolors.ENDC)
    print("\n")
    time.sleep(3)
    print(bcolors.BOLD + "A battle ship has arrived. You frown, exhausted and wounded from your battles. Who could it be? The answer came soon enough. Getting down from his ship, there he is." , bcolors.ENDC)
    print("\n")
    time.sleep(3)
    print(bcolors.BOLD + "The purple grape in person. It's Super Villain Thanos. \nHe resurrected", villain.name, "and his health increased 200% to", villain.health , bcolors.ENDC)
    print("\n")
    time.sleep(3)
    print(bcolors.BOLD + "Since you moved to level 2, as a blessing from the AllFather Odin,\n your health is restored and your strength is increased" + bcolors.ENDC)
    print("\n")
    time.sleep(3)
    print(bcolors.BOLD + "This level is going to be more challenging. Be prepared. \nIn this level you have to show your intelligence, strength, and strategical mind" + bcolors.ENDC )
    print("\n")
    time.sleep(3)
    print(bcolors.Red + villain.name, "is back \nand kidnapped your dear friends Krutika and Shreenidhi. \nYou need to pass three stages to rescue your friends, \nand for that you have to answer three questions correctly out of five." + bcolors.ENDC)
    print("\n")
    time.sleep(3)
    print(bcolors.BOLD + "Be careful the longer it takes you and the more wrong answers the more they will suffer" + bcolors.ENDC)
    print("\n")
    time.sleep(3)
    print(bcolors.Grey + "Answer these questions carefully, \nthe fate of your city, friends and even more the whole universe is in your poor mediocre hands" + bcolors.ENDC)
    print("\n")
    time.sleep(3)
    score = 0
    #Question 1
    ans=''
    a1="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a1=="0"):
        ans1 = input(bcolors.UNDERLINE + "Where is Thor from? \n1. Asgard \n2.New York \n3.Wakanda \nAnswer: ")
        if ans1 == '1':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score, bcolors.ENDC)
            print("\n")
            a1="1"
        elif ans1 == '2' or ans1 == '3':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "The answer was Asgard, you buffoon" + bcolors.ENDC)
            print("\n")
            a1="1"
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
       
    #Question 2
    ans=''
    a2="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a2=="0"):
        ans2 = input(bcolors.UNDERLINE + "How many Infinity Stones are there? \n1. Four \n2.Five \n3.Six \nAnswer: ")
        if ans2 == '3':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a2='1'
        elif ans2 == '1' or ans2 == '2':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "The answer is six, 1.Space Stone, 2. Mind Stone, 3. Reality stone, 4. Power Stone, 5. Time Stone, 6. Soul stone, how could you miss that?" + bcolors.ENDC)
            print("\n")
            a2='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
    #Question 3
    ans=''
    a3="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a3=="0"):
        ans3 = input(bcolors.UNDERLINE + "What is the name of Thor's hammer? \n1. Mjolnir \n2.Stormbreaker \n3.Thormer \nAnswer: " + bcolors.ENDC)
        if ans3 == '1':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a3='1'
        elif ans3 == '2' or ans3 == '3':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "The answer is Mjolnir. Come on! Are you even trying? This was easy" + bcolors.ENDC)
            print("\n")
            a3='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
    #Question 4
    ans=''
    a4="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a4=="0"):
        ans4 = input(bcolors.UNDERLINE + "What was Tony Stark's father name? \n1.Howard Potts  \n2. Howard Stark \n3. Benjamin Stark \nAnswer: " + bcolors.ENDC)
        if ans4 == '2':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a4='1'
        elif ans4 == '1' or ans4 == '3':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "The answer is Howard Stark. You cannot even respect the dead." + bcolors.ENDC)
            print("\n")
            a4='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
    #Question 5
    ans=''
    a5="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a5=="0"):
        ans5 = input(bcolors.UNDERLINE + "Which is better? \n1.Marvel \n2. DC \nAnswer: " + bcolors.ENDC)
        if ans5 == '1':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a5='1'
        elif ans5 == '2':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "Marvel is always better than DC. We get it, you prefer people who wear their underwear over their pants." + bcolors.ENDC)
            score -= 1
            print(bcolors.Red + "Your score is", score , bcolors.ENDC)
            print("\n")
            a5='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
            print(bcolors.Red + "Your total score is", score , bcolors.ENDC)
            print("\n")
            
    if score >= 3:
        print(bcolors.Magenta + "You've rescued your friends. \nBut they're in a bad state. \nShreenidhi has seen too much, he cannot even stand straight." + bcolors.ENDC)
        print("\n")
        time.sleep(2)
        print(bcolors.Magenta + "Krutika is bleeding heavily. \nYou took so long to come and save them. \nHow can you be trusted to save the Universe if you can't even save your friends." + bcolors.ENDC)
        print("\n")
        time.sleep(2)
        print(bcolors.Magenta + "But not all hope is lost. \nYou were so worried you could not work properly. \nNow all your attention is focused on defeating this vile" , villain.name + bcolors.ENDC)
        print("\n")
        time.sleep(2)
        print("Now you have 3 options to try to defeat", villain.name)
        print("\n")
        time.sleep(2)
        while villain.health > 0:
            choice = input("1. Thunder blast \n2. Smart Missiles \n3. Energy blade " )
            if choice == "1":
                print("You used Thunder blast to attack the", villain.name)
                print("\n")
                hitchance = random.randint(0,10)
                if hitchance > 4:
                    villain.health = villain.health - hero.strength
                    print("You succesfully attacked", villain.name, " and his health decreased to", villain.health )
                    if villain.health > 0:
                        hero.health = hero.health - villain.strength
                        print(villain.name, "counter-attacked you and your health decreased to", hero.health)
                        if hero.health <= 0:
                            fail()
                            break
                        else:
                            print("you have 3 options")
                            print("\n")
                    else :
                        print("Congrats!", villain.name, "has been defeated")
                        print("\n")
                        stage_3(thanos)
            
                else:
                    print("You tried to attack but" ,villain.name, " is using his shield and your attack failed")
                    print("\n")
                    hero.health = hero.health - villain.strength
                    print(villain.name, "attacked you & you took full damage. Your health is", hero.health)
                    print("\n")
                    if hero.health <= 0:
                        fail()
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
            elif choice == "2":
                print("You used Smart Missiles to attack the", villain.name)
                print("\n")
                hitchance = random.randint(0,10)
                if hitchance > 3:
                    villain.health = villain.health - hero.strength
                    print("You succesfully attacked", villain.name, " and his health decreased to", villain.health )
                    print("\n")
                    if villain.health > 0:
                        hero.health = hero.health - villain.strength
                        print(villain.name, " attacked you and your health decreased to", hero.health)
                        print("\n")
                        if hero.health <= 0:
                            fail()
                            break
                        else:
                            print("you have 3 options")
                            print("\n")
                    else :
                        print("yay!!!You have defeated the", villain.name)
                        print("\n")
                        time.sleep(2)
                        stage_3(thanos)
                else:
                    print("you attacked but" ,villain.name, " is using his shield and your attack failed")
                    print("\n")
                    time.sleep(2)
                    hero.health = hero.health - villain.strength
                    print(villain.name, "attacked you & you took full damage. Your health is", hero.health)
                    print("\n")
                    time.sleep(2)
                    if hero.health <= 0:
                        fail()
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
            elif choice == "3":
                print("You used Energy blade to attack the", villain.name)
                print("\n")
                time.sleep(2)
                hitchance = random.randint(0,10)
                if hitchance > 3:
                    villain.health = villain.health - hero.strength
                    print("You succesfully attacked", villain.name, " and his health decreased to", villain.health )
                    print("\n")
                    time.sleep(2)
                    if villain.health > 0:
                        hero.health = hero.health - villain.strength
                        print(villain.name, " attacked you and your health decreased to", hero.health)
                        print("\n")
                        time.sleep(2)
                        if hero.health <= 0:
                            fail()
                            break
                        else:
                            print("you have 3 options")
                            print("\n")
                    else :
                        print("yay!!!You have defeated the", villain.name)
                        print("\n")
                        time.sleep(2)
                        stage_3(thanos)
                else:
                    print("you attacked but" ,villain.name, " is using his shield and your attack failed")
                    print("\n")
                    time.sleep(2)
                    hero.health = hero.health - villain.strength
                    print(villain.name, "attacked you & you took full damage. Your health is", hero.health)
                    print("\n")
                    time.sleep(2)
                    if hero.health <= 0:
                        fail()
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
            else:
                print("Invalid Selection, only press 1,2 or 3")
                print("\n")
                time.sleep(2)
    else: 
        print("Exhausted and deadly wounded, you had no choice but to kneel when faced against", villain.name, ".\n He destroyed the city")
        fail()
        
            
def stage_3(thanos):
    hero.health = 20
    hero.strength = 15
    import numpy as np
    from matplotlib import pyplot as plt
    
    for letter in '...':
        print(letter)
    print("Since you moved to level 3 defeating your last opponent. \nOdin, in his allmighty glory (even though he didn't lift a finger to help), increased your health  and strength")
    print("\n")
    for letter in '....':
        print(letter)
        time.sleep(2)
    print(""" 
████████╗██╗  ██╗ █████╗ ███╗   ██╗ ██████╗ ███████╗    ██╗███████╗    ██╗  ██╗███████╗██████╗ ███████╗
╚══██╔══╝██║  ██║██╔══██╗████╗  ██║██╔═══██╗██╔════╝    ██║██╔════╝    ██║  ██║██╔════╝██╔══██╗██╔════╝
   ██║   ███████║███████║██╔██╗ ██║██║   ██║███████╗    ██║███████╗    ███████║█████╗  ██████╔╝█████╗  
   ██║   ██╔══██║██╔══██║██║╚██╗██║██║   ██║╚════██║    ██║╚════██║    ██╔══██║██╔══╝  ██╔══██╗██╔══╝  
   ██║   ██║  ██║██║  ██║██║ ╚████║╚██████╔╝███████║    ██║███████║    ██║  ██║███████╗██║  ██║███████╗
   ╚═╝   ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═══╝ ╚═════╝ ╚══════╝    ╚═╝╚══════╝    ╚═╝  ╚═╝╚══════╝╚═╝  ╚═╝╚══════╝
                                                                                                       """)
    print("Thanos is here to collect the space stone himself. \nHis lackeys are not efficient enough. It is hard to find good help these days.") 
    print("\n")
    time.sleep(2)
    print("This is the last stone he needs to possess before he can wipe out half of the universe")
    print("\n")
    time.sleep(2)
    print(bcolors.Red + "In a furious rage, he killed Dr. Abdul Samad for trying to escape him. \nThanos took the poor doctor's head between his gigantic hands and pressed. You could only weep at your friend's cruel demise." + bcolors.ENDC)
    print("\n")
    time.sleep(2)
    print("His assistant Océane fleed when faced with this immense danger.") 
    print("\n")
    time.sleep(2)
    print("He heard from the dying doctor that the stone was kept somewhere else. \nLooking around, he found the name of Dr Aparna and decided to pay her a courtesy call.") 
    print("\n")
    time.sleep(2)
    print("Now the Mad Titan is going towards Dr. Aparna's facility")
    print("\n")
    time.sleep(2)
    print("You have to stop Thanos from getting the stone and wiping out half of the universe!")
    print("\n")
    time.sleep(2)
    print("The fate of the Universe is in your hands")
    print("\n")
    time.sleep(2)
    print("Your friend Krutika, who is a data scientist, tried to find some of the data of Thanos we have, which might help you in the battle")
    print("\n")
    time.sleep(2)
    print(bcolors.Red + "Unfortunately, she ended up being a casualty when Thanos reach the facility and died trying to send that information to you." + bcolors.ENDC)
    print("\n")
    time.sleep(2)
    print("She could not transfer everything, \nbut your close friend and her colleague Shreenidhi finished the transfer in her memory.")
    print("\n")
    time.sleep(3)
    print("These are some stats which might help you in the battle against Mad Titan Thanos")
    stats = ['Strength', 'Health', 'Intelligence', 'Power', 'Agility']
    numbers = ['12', '20', '25', '28', '40']
    ind = np.arange(len(stats))
    ind
    plt.bar(ind, numbers)
    plt.xticks(ind, stats)
    plt.show()
    time.sleep(3)
    print("This level is going to be much more challenging. \nIn this level you have to show high intelligence, strength, and strategic skills" )
    print("\n")
    time.sleep(2)
    print("To Stop Thanos from stealing the stone, you have to reach at Dr. Aparna's facility before him")
    print("\n")
    time.sleep(2)
    print("Answer these questions carefully and within 30 seconds, to reach before Thanos.")
    print("\n")
    time.sleep(2)
    print("You have to score 5/7")
    print("\n")
    time.sleep(2)
    print("The fate of the Universe is in your hands")
    time.sleep(2)
    score = 0
    #Question 6
    ans=''
    a6="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a6=="0"):
        ans6 = input(bcolors.UNDERLINE + "Where is Wakanda located? \n1. Africa \n2.Asia \n3.Europe \nAnswer: " + bcolors.ENDC)
        if ans6 == '1':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a6='1'
        elif ans6 == '2' or ans6 == '3':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "The answer is Africa. You're unworthy to be an Avenger" + bcolors.ENDC)
            print("\n")
            a6='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
    #Question 7
    ans=''
    a7="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a7=="0"):
        ans7 = input(bcolors.UNDERLINE + "Who is the love interest of Tony Stark \n1. Pepper Potts \n2. Peggy Carter \n3.Natasha Romanoff \nAnswer: " + bcolors.ENDC)
        if ans7 == '1':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a7='1'
        elif ans7 == '3' or ans7 == '2':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "The answer is Pepper Potts. Come on! You were at the wedding! Were you so drunk you cannot remember?" + bcolors.ENDC)
            print("\n")
            a7='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
    #Question 8
    ans=''
    a8="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a8=="0"):
        ans8 = input(bcolors.UNDERLINE + "Who can lift Thor's hammer? \n1. Tony Stark \n2. Nick Fury \n3. Captain America \nAnswer: " + bcolors.ENDC)
        if ans8 == '3':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a8='1'
        elif ans8 == '2' or ans8 == '1':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "The answer is Captain America. So disrespectful towards our own emblem of patriotism" + bcolors.ENDC)
            print("\n")
            a8='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
    #Question 9
    ans=''
    a9="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a9=="0"):
        ans9 = input(bcolors.UNDERLINE + "Which actor portrays the role of Iron Man in MCU? \n1. Chris Hemsworth  \n2. Robert Downey Jr \n3. Chadwick Boseman \nAnswer: " + bcolors.ENDC)
        if ans9 == '2':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score, bcolors.ENDC)
            print("\n")
            a9='1'
        elif ans9 == '1' or ans9 == '3':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "The answer is Robert Downey Jr. Dissapointed. Just dissapointed." + bcolors.ENDC)
            print("\n")
            a9='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
    #Question 10
    ans=''
    a10="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a10=="0"):
        ans10 = input(bcolors.UNDERLINE + "What is the name of Captain America \n1.Steve Rogers \n2. Tony Stark \n3. Clint Barton \nAnswer: " + bcolors.ENDC)
        if ans10 == '1':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a10='1'
        elif ans10 == '2' or ans10 == '3':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "Steve Rogers is Captain America. Which planet are you from? Even people in the 40s would know!" + bcolors.ENDC)
            print("\n")
            a10='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
            print(bcolors.Red + "Your total score is", score , bcolors.ENDC)
            print("\n")
    #Question 10
    ans=''
    a11="0"
    while (ans!='1'or  ans!='2' or ans!='3') and (a11=="0"):
        ans11 = input(bcolors.UNDERLINE + "Who is known as Mad Titan \n1.Thanos \n2. Tony Stark \n3. Red Hulk \nAnswer: " + bcolors.ENDC)
        if ans11 == '1':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a11='1'
        elif ans11 == '2' or ans11 == '3':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "Mad Titan is Thanos. Dude. We literally spelled it out not even 2 minutes ago." + bcolors.ENDC)
            print("\n")
            a11='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
            print(bcolors.Red + "Your total score is", score , bcolors.ENDC)
            print("\n")
    #Question 12
    ans=''
    a12="0"
    while (ans!='1'or  ans!='2') and (a12=="0"):
        ans12 = input(bcolors.UNDERLINE + "Which is better? \n1.Marvel \n2. DC \nAnswer: " + bcolors.ENDC)
        if ans12 == '1':
            score += 1
            print(bcolors.Green + "Right Answer" + bcolors.ENDC)
            print(bcolors.Green + "Your score is", score , bcolors.ENDC)
            print("\n")
            a12='1'
        elif ans12 == '2':
            print(bcolors.Red + "Sorry You chose the wrong answer" + bcolors.ENDC)
            print(bcolors.Red + "Marvel is always better than DC. This is not the first time we're telling you. You really must love underwears." + bcolors.ENDC)
            score -= 1
            print(bcolors.Red + "Your score is", score , bcolors.ENDC)
            print("\n")
            a12='1'
        else:
            print(bcolors.Red + "Invalid selection, You're only allowed to press 1,2 or 3" + bcolors.ENDC)
            print("\n")
            print(bcolors.Red + "Your total score is", score , bcolors.ENDC)
            print(score)
            print("\n")
    if score >= 5:
        print("You reached at Dr. Aparna's facility before Thanos and took the stone from her and transported it to your facility" + bcolors.ENDC)
        print("\n")
        time.sleep(2)
        print(bcolors.Red + "Furious, Thanos tortured and killed Dr. Aparna and found your location from her databooks.\nYou found out later that her body was disfigured beyond recognition." + bcolors.ENDC)
        print("\n")
        for letter in '....':
            print(letter)
            time.sleep(2)
        print(bcolors.Red + "Thanos arrived at your facility and he was furious. \nIn a murderous rage, he threw your friend Shreenidhi against the wall, \nin front of your eyes as he was telling you about your other friends' deaths. \nYou saw his mangled body fall from the wall in a pool of blood." + bcolors.ENDC)
        print("\n")
        time.sleep(2)
        print("Now, you have the Space Stone, coated in the blood of your friends, \nand it is time for you to aim for revenge. \nNot a glorious reason but you just lost everyone you cared about.")
        print("\n")
        time.sleep(2)
        print("With the help of Professor Chase Kusterer you created 3 different weapons using Space Stone.")
        print("\n")
        while thanos.health > 0:
            choice = input("1. Space Stone Hammer \n2. Space Stone Repulsor \n3. Space Stone Energy Blast " )
            if choice == "1":
                print("You used Space Stone Hammer to attack Thanos")
                print("\n")
                hitchance = random.randint(0,10)
                if hitchance > 4:
                    thanos.health = thanos.health - hero.strength
                    print("You succesfully attacked Thanos and his health decreased to", thanos.health )
                    if thanos.health > 0:
                        hero.health = hero.health - thanos.strength
                        print("Thanos attacked you and your health decreased to", hero.health)
                        if hero.health <= 0:
                            print("Sorry, You lost Thanos wiped out half of the Universe. \nYou discovered too late that the doctor's assistant, Océane, had helped him learn about your weaknesses.")
                            print("\n")
                            for letter in '....':
                                print(letter)
                                time.sleep(2)
                            print(bcolors.Red + """
╦ ╦╔═╗╦ ╦  ╔═╗╔═╗╦╦  ╔═╗╔╦╗
╚╦╝║ ║║ ║  ╠╣ ╠═╣║║  ║╣  ║║
 ╩ ╚═╝╚═╝  ╚  ╩ ╩╩╩═╝╚═╝═╩╝""" + bcolors.ENDC)
                            break
                        else:
                            print("you have 3 options")
                            print("\n")
                    else :
                        print("Hurray!! Thanos has been defeated! The Universe is safe")
                        print("\n")
                        print("You saved the universe, We're proud of you. Now you can go grieve your friends in peace.")
                        for letter in '....':
                            print(letter)
                            time.sleep(2)
                        print(bcolors.Green + """
╦ ╦╔═╗╦ ╦  ╦ ╦╔═╗╔╗╔
╚╦╝║ ║║ ║  ║║║║ ║║║║
 ╩ ╚═╝╚═╝  ╚╩╝╚═╝╝╚╝""" + bcolors.ENDC)
                else:
                    print("You attacked but Thanos used his terribly powerful gauntlet to stop you and your attack failed")
                    print("\n")
                    hero.health = hero.health - thanos.strength
                    print("Thanos attacked you & you took full damage. Your health is", hero.health)
                    print("\n")
                    if hero.health <= 0:
                        print("Sorry, You lost Thanos wiped out half of the Universe. \nYou discovered too late that the doctor's assistant, Océane, had helped him learn about your weaknesses.")
                        print("\n")
                        for letter in '....':
                            print(letter)
                            time.sleep(2)
                        print(bcolors.Red + """
╦ ╦╔═╗╦ ╦  ╔═╗╔═╗╦╦  ╔═╗╔╦╗
╚╦╝║ ║║ ║  ╠╣ ╠═╣║║  ║╣  ║║
 ╩ ╚═╝╚═╝  ╚  ╩ ╩╩╩═╝╚═╝═╩╝""" + bcolors.ENDC)
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
            elif choice == "2":
                print("You used Space Stone Repulsor to attack Thanos")
                print("\n")
                hitchance = random.randint(0,10)
                if hitchance > 3:
                    thanos.health = thanos.health - hero.strength
                    print("You succesfully attacked Thanos and his health decreased to", thanos.health )
                    print("\n")
                    if thanos.health > 0:
                        hero.health = hero.health - thanos.strength
                        print("Thanos attacked you and your health decreased to", hero.health)
                        print("\n")
                        if hero.health <= 0:
                            print("Sorry, You lost Thanos wiped out half of the Universe. \nYou discovered too late that the doctor's assistant, Océane, had helped him learn about your weaknesses.")
                            print("\n")
                            for letter in '....':
                                print(letter)
                                time.sleep(2)
                            print(bcolors.Red + """
╦ ╦╔═╗╦ ╦  ╔═╗╔═╗╦╦  ╔═╗╔╦╗
╚╦╝║ ║║ ║  ╠╣ ╠═╣║║  ║╣  ║║
 ╩ ╚═╝╚═╝  ╚  ╩ ╩╩╩═╝╚═╝═╩╝""" + bcolors.ENDC)
                            break
                        else:
                            print("you have 3 options")
                            print("\n")
                    else :
                        print("Hurray!!You have defeated Thanos and saved everyone!")
                        print("\n")
                        print("You saved the universe, We're proud of you. Now, you have time to grieve all your friends' deaths in peace.")
                        for letter in '....':
                            print(letter)
                            time.sleep(2)
                        print(bcolors.Green + """
╦ ╦╔═╗╦ ╦  ╦ ╦╔═╗╔╗╔
╚╦╝║ ║║ ║  ║║║║ ║║║║
 ╩ ╚═╝╚═╝  ╚╩╝╚═╝╝╚╝""" + bcolors.ENDC)
                else:
                    print("You attacked but Thanos is used his awfully powerful gauntlet to stop you and your attack failed")
                    print("\n")
                    hero.health = hero.health - thanos.strength
                    print(thanos.name, "attacked you & you took full damage. Your health is", hero.health)
                    print("\n")
                    if hero.health <= 0:
                        print("Sorry, You lost Thanos wiped out half of the Universe. \nYou discovered too late that the doctor's assistant, Océane, had helped him learn about your weaknesses.")
                        print("\n")
                        for letter in '....':
                            print(letter)
                            time.sleep(2)
                        print(bcolors.Red + """
╦ ╦╔═╗╦ ╦  ╔═╗╔═╗╦╦  ╔═╗╔╦╗
╚╦╝║ ║║ ║  ╠╣ ╠═╣║║  ║╣  ║║
 ╩ ╚═╝╚═╝  ╚  ╩ ╩╩╩═╝╚═╝═╩╝""" + bcolors.ENDC) 
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
            elif choice == "3":
                print("You used Space Stone Energy Blast to attack the Thanos")
                print("\n")
                hitchance = random.randint(0,10)
                if hitchance > 2:
                    thanos.health = thanos.health - hero.strength
                    print("You succesfully attacked and Thanos his health decreased to", thanos.health )
                    print("\n")
                    if thanos.health > 0:
                        hero.health = hero.health - thanos.strength
                        print(" Thanos attacked you and your health decreased to", hero.health)
                        print("\n")
                        if hero.health <= 0:
                            print("Sorry, You lost Thanos wiped out half of the Universe. \nYou discovered too late that the doctor's assistant, Océane, had helped him learn about your weaknesses.")
                            print("\n")
                            for letter in '....':
                                print(letter)
                                time.sleep(2)
                            print(bcolors.Red + """
╦ ╦╔═╗╦ ╦  ╔═╗╔═╗╦╦  ╔═╗╔╦╗
╚╦╝║ ║║ ║  ╠╣ ╠═╣║║  ║╣  ║║
 ╩ ╚═╝╚═╝  ╚  ╩ ╩╩╩═╝╚═╝═╩╝""" + bcolors.ENDC)
                            break
                        else:
                            print("you have 3 options")
                            print("\n")
                    else :
                        print("Hurray!!You have defeated Thanos. You save the world!")
                        print("\n")
                        print("You saved the universe, We're proud of you! Now, you can go and rest, and process your grief in peace and calm.")
                        for letter in '....':
                            print(letter)
                            time.sleep(2)
                        print(bcolors.Green + """
╦ ╦╔═╗╦ ╦  ╦ ╦╔═╗╔╗╔
╚╦╝║ ║║ ║  ║║║║ ║║║║
 ╩ ╚═╝╚═╝  ╚╩╝╚═╝╝╚╝""" + bcolors.ENDC)
                else:
                    print("You attacked but Thanos is used his horribly terrific his gauntlet to stop you and your attack failed")
                    print("\n")
                    hero.health = hero.health - thanos.strength
                    print("Thanos attacked you & you took full damage. Your health is", hero.health)
                    print("\n")
                    if hero.health <= 0:
                        print("Sorry, You lost Thanos wiped out half of the Universe. \nYou discovered too late that the doctor's assistant, Océane, had helped him learn about your weaknesses.")
                        print("\n")
                        for letter in '....':
                            print(letter)
                            time.sleep(2)
                        print(bcolors.Red + """
╦ ╦╔═╗╦ ╦  ╔═╗╔═╗╦╦  ╔═╗╔╦╗
╚╦╝║ ║║ ║  ╠╣ ╠═╣║║  ║╣  ║║
 ╩ ╚═╝╚═╝  ╚  ╩ ╩╩╩═╝╚═╝═╩╝""" + bcolors.ENDC)
                        break
                    else:
                        print("you have 3 options")
                        print("\n")
            else:
                print("Invalid Selection, only press 1,2 or 3")
                print("\n")
    else:
        print("Sorry, You lost Thanos wiped out half of the Universe. \nYou discovered too late that the doctor's assistant, Océane, had helped him learn about your weaknesses.")
        print("\n")
        for letter in '....':
            print(letter)
            time.sleep(2)
        print(bcolors.Red + """
╦ ╦╔═╗╦ ╦  ╔═╗╔═╗╦╦  ╔═╗╔╦╗
╚╦╝║ ║║ ║  ╠╣ ╠═╣║║  ║╣  ║║
 ╩ ╚═╝╚═╝  ╚  ╩ ╩╩╩═╝╚═╝═╩╝""" + bcolors.ENDC)
    
start_1()
hero = myhero()

battleground()
